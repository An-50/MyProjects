# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Второй-номер-для-экспериментов" data-toc-modified-id="Второй-номер-для-экспериментов-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Второй номер для экспериментов</a></span></li><li><span><a href="#Импорт-библиотек" data-toc-modified-id="Импорт-библиотек-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Импорт библиотек</a></span></li><li><span><a href="#Подготовим-api_id-и-api_hash" data-toc-modified-id="Подготовим-api_id-и-api_hash-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовим api_id и api_hash</a></span></li><li><span><a href="#Как-все-будет-работать" data-toc-modified-id="Как-все-будет-работать-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Как все будет работать</a></span></li><li><span><a href="#Файл-авторизации-и-тестирования-pyro_auth.py" data-toc-modified-id="Файл-авторизации-и-тестирования-pyro_auth.py-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Файл авторизации и тестирования <code>pyro_auth.py</code></a></span></li><li><span><a href="#Файл-выгрузки-(pyro_run.py)" data-toc-modified-id="Файл-выгрузки-(pyro_run.py)-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Файл выгрузки (<code>pyro_run.py</code>)</a></span></li><li><span><a href="#Загрузим-полученный-файл" data-toc-modified-id="Загрузим-полученный-файл-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Загрузим полученный файл</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-вакансию" data-toc-modified-id="Посмотрим-вакансию-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Посмотрим вакансию</a></span></li><li><span><a href="#Преобразуем-дату" data-toc-modified-id="Преобразуем-дату-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Преобразуем дату</a></span></li><li><span><a href="#Достанем-из-столбца-чат-в-фомате-json-IDшник-и-название-чата" data-toc-modified-id="Достанем-из-столбца-чат-в-фомате-json-IDшник-и-название-чата-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Достанем из столбца чат в фомате json IDшник и название чата</a></span></li><li><span><a href="#Посмотрим-те-вакансии-где-есть,-аналитик" data-toc-modified-id="Посмотрим-те-вакансии-где-есть,-аналитик-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Посмотрим те вакансии где есть, аналитик</a></span></li><li><span><a href="#Пометим-True-или-False-там-где-у-нас-совпадение" data-toc-modified-id="Пометим-True-или-False-там-где-у-нас-совпадение-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Пометим True или False там где у нас совпадение</a></span></li><li><span><a href="#Чтобы-нам-удобно-было-смотреть-ваканисии-добавим-кнопку" data-toc-modified-id="Чтобы-нам-удобно-было-смотреть-ваканисии-добавим-кнопку-7.6"><span class="toc-item-num">7.6&nbsp;&nbsp;</span>Чтобы нам удобно было смотреть ваканисии добавим кнопку</a></span></li></ul></li><li><span><a href="#Достанем-все-ссылки" data-toc-modified-id="Достанем-все-ссылки-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Достанем все ссылки</a></span></li><li><span><a href="#Парсим-ссылки" data-toc-modified-id="Парсим-ссылки-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Парсим ссылки</a></span></li><li><span><a href="#Удобный-просмотр" data-toc-modified-id="Удобный-просмотр-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Удобный просмотр</a></span></li><li><span><a href="#Список-телеграм-каналов,-откуда-еще-можно-тащить-вакансии-(для-примера)" data-toc-modified-id="Список-телеграм-каналов,-откуда-еще-можно-тащить-вакансии-(для-примера)-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Список телеграм каналов, откуда еще можно тащить вакансии (для примера)</a></span></li><li><span><a href="#Домашнее-задание" data-toc-modified-id="Домашнее-задание-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Домашнее задание</a></span></li><li><span><a href="#Форма-обратной-связи-по-элективу-&quot;Парсер-вакансий&quot;" data-toc-modified-id="Форма-обратной-связи-по-элективу-&quot;Парсер-вакансий&quot;-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Форма обратной связи по элективу "Парсер вакансий"</a></span></li></ul></div>

# %% [markdown]
# # Парсер вакансий TG

# %% [markdown]
# API Telegram: https://core.telegram.org/api \
# Чтобы парсить телеграм будем использовать библиотеку [Pyrogram](https://docs.pyrogram.org/intro/quickstart)\
# Сначала создаем приложение, чтобы получить доступ к Telegram API. https://my.telegram.org/apps \

# %% [markdown]
# ### Второй номер для экспериментов
#
# <a href="https://moscow.megafon.ru/corporate/mobile/options/calls/dop_nomer.html">Мегафон</a><br>
# <a href="https://msk.tele2.ru/option/second-number">ТЕЛЕ2</a>

# %% [markdown]
# Установим pyrogram и tgcrypto (его рекомендуют в документации к Pyrogram):\
# https://docs.pyrogram.org/intro/install

# %%
# !pip3 install pyrogram tgcrypto

# %% [markdown]
# Нам потребуется python-dotenv для автоматизации добавления ключей в окружение чтобы не хранить их в коде

# %%
# !pip3 install python-dotenv #

# %% [markdown]
# Ключи это **App api_id** и **App api_hash** c сайта telegram https://my.telegram.org/apps
#
# В файл dot.env записываем **API_ID** и **API_HASH**

# %% [markdown]
# ### Импорт библиотек

# %%
import pyrogram
import requests
import numpy as np
from bs4 import BeautifulSoup
from dotenv import load_dotenv
import os
from pyrogram import Client
import pandas as pd
import json
from datetime import datetime
import re
from IPython.core.display import display, HTML, clear_output
import ipywidgets as widgets

# %%
pd.set_option('display.max_columns', 20) #устанавливаем максимальное число отображаемых колонок
pd.set_option('display.max_rows', 100)
pd.set_option('max_colwidth', 300)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %% [markdown]
# ### Подготовим api_id и api_hash

# %%
dotenv_path = os.path.join('dot.env')
if os.path.exists(dotenv_path):
    load_dotenv(dotenv_path)

# %%
os.environ['DEMO']
# Out:
# 'demo'

# %%
API_ID = os.environ['API_ID']
API_HASH = os.environ['API_HASH']

# %% [markdown]
# ### Как все будет работать

# %% [markdown]
# Запишем код в файлы *.py*.
#
# Первый - тестовый для авторизации. Его запустим прямо в терминале, чтобы ввести телефон и код подтверждения.
#
# Второй - основной для выгрузки сообщений. Мы его можем запустить прямо отсюда.

# %% [markdown]
# ### Файл авторизации и тестирования `pyro_auth.py`

# %% [markdown]
# После успешного входа у нас появится файл ```my_account.session```.

# %% [markdown]
# ### Файл выгрузки (`pyro_run.py`)

# %% [markdown]
# Первая часть аналогичная файлу авторизации. Только добавляется pandas
# ```python
# from pyrogram import Client
# import os
# from dotenv import load_dotenv
# import pandas as pd
#
#
# path = os.path.dirname(os.path.abspath(__file__))
#
# dotenv_path = os.path.join(path + '/dot.env') #
# if os.path.exists(dotenv_path):
#     load_dotenv(dotenv_path)
#
# API_ID = os.environ['API_ID']
# API_HASH = os.environ['API_HASH']
# ```

# %% [markdown]
# Затем перечислим чаты, из которых мы будем брать сообщения: \
# https://t.me/datajob \
# https://t.me/foranalysts \
# https://t.me/datasciencejobs \
# **На выбранные каналы подписываемся заранее**
# ```python
# targets = ['datajob', 'foranalysts', 'datasciencejobs']
# ```

# %% [markdown]
# targets = ['datajob', 'foranalysts', 'datasciencejobs', 'analyst_job', 'bds_job']

# %% [markdown]
# Дальше создадим список, где будем хранить сообщения:
# ```python
# all_messages = []
# ```

# %% [markdown]
# Основная (рабочая) часть нашего кода выгрузки:
# ```python
# try:
#     with Client("my_account", API_ID, API_HASH) as app:
#         for target in targets:
#             for message in app.iter_history(target, limit=20):
#                 all_messages.append([message.sender_chat, message.message_id, message.date, message.text, message.entities])
#
#     df = pd.DataFrame(all_messages)
#     df.columns = ["chat", "message_id", "date", "text", "entities"]
#     df.to_csv(path + '/telegram.csv', index=False)
#     print('Success: ', path + '/telegram.csv')
# except Exception as e:
#     print('Error: ', e)
# ```

# %%
# %%bash
# python3 pyro_run.py #если у вас один питон или Python 3 стоит по умолчанию, то код будет: python pyro_run.py

# %% [markdown]
# ### Загрузим полученный файл

# %%
telegram = pd.read_csv('telegram.csv')

# %%
telegram.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   chat        60 non-null     object
#  1   message_id  60 non-null     int64
#  2   date        60 non-null     int64
#  3   text        52 non-null     object
#  4   entities    52 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 2.5+ KB

# %%
telegram = telegram.dropna().reset_index(drop=True) #сбросим индекс

# %%
telegram.head(3)
# Out:
#                                                                                                                                                                                                                                                                                                           chat  \
# 0  {\n    "_": "Chat",\n    "id": -1001483488834,\n    "type": "channel",\n    "is_verified": false,\n    "is_restricted": false,\n    "is_creator": false,\n    "is_scam": false,\n    "is_fake": false,\n    "title": "Data jobs — вакансии по data science, анализу данных, аналитике, искусственному ин...
# 1  {\n    "_": "Chat",\n    "id": -1001483488834,\n    "type": "channel",\n    "is_verified": false,\n    "is_restricted": false,\n    "is_creator": false,\n    "is_scam": false,\n    "is_fake": false,\n    "title": "Data jobs — вакансии по data science, анализу данных, аналитике, искусственному ин...
# ...

# %% [markdown]
# #### Посмотрим вакансию

# %%
print(telegram.iloc[2]['text'].lower()) #к нижему регистру чтобы искать регулярные выражения ниже
# Out:
# 👔 data scientist
# ⛳️ ресо-гарантия
# 💼🥁работа в офисе
# 💵 зарплата на собеседовании
#
# подробнее: https://proglib.io/vacancies/data-scientist-reso-garantiya-2022-04-10

# %%
telegram
# Out:
#                                                                                                                                                                                                                                                                                                            chat  \
# 0   {\n    "_": "Chat",\n    "id": -1001483488834,\n    "type": "channel",\n    "is_verified": false,\n    "is_restricted": false,\n    "is_creator": false,\n    "is_scam": false,\n    "is_fake": false,\n    "title": "Data jobs — вакансии по data science, анализу данных, аналитике, искусственному ин...
# 1   {\n    "_": "Chat",\n    "id": -1001483488834,\n    "type": "channel",\n    "is_verified": false,\n    "is_restricted": false,\n    "is_creator": false,\n    "is_scam": false,\n    "is_fake": false,\n    "title": "Data jobs — вакансии по data science, анализу данных, аналитике, искусственному ин...
# ...

# %% [markdown]
# #### Преобразуем дату

# %%
telegram.date = pd.to_datetime(telegram['date'],unit='s')

# %%
telegram.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   chat        52 non-null     object
#  1   message_id  52 non-null     int64
#  2   date        52 non-null     datetime64[ns]
#  3   text        52 non-null     object
#  4   entities    52 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.2+ KB

# %%
telegram.head(3)
# Out:
#                                                                                                                                                                                                                                                                                                           chat  \
# 0  {\n    "_": "Chat",\n    "id": -1001483488834,\n    "type": "channel",\n    "is_verified": false,\n    "is_restricted": false,\n    "is_creator": false,\n    "is_scam": false,\n    "is_fake": false,\n    "title": "Data jobs — вакансии по data science, анализу данных, аналитике, искусственному ин...
# 1  {\n    "_": "Chat",\n    "id": -1001483488834,\n    "type": "channel",\n    "is_verified": false,\n    "is_restricted": false,\n    "is_creator": false,\n    "is_scam": false,\n    "is_fake": false,\n    "title": "Data jobs — вакансии по data science, анализу данных, аналитике, искусственному ин...
# ...

# %% [markdown]
# #### Достанем из столбца чат в фомате json IDшник и название чата

# %%
telegram["chat_id"] = telegram["chat"].apply(lambda x: json.loads(x)['id'])
telegram["title"] = telegram["chat"].apply(lambda x: json.loads(x)['title'])

# %%
telegram.head(3)
# Out:
#                                                                                                                                                                                                                                                                                                           chat  \
# 0  {\n    "_": "Chat",\n    "id": -1001483488834,\n    "type": "channel",\n    "is_verified": false,\n    "is_restricted": false,\n    "is_creator": false,\n    "is_scam": false,\n    "is_fake": false,\n    "title": "Data jobs — вакансии по data science, анализу данных, аналитике, искусственному ин...
# 1  {\n    "_": "Chat",\n    "id": -1001483488834,\n    "type": "channel",\n    "is_verified": false,\n    "is_restricted": false,\n    "is_creator": false,\n    "is_scam": false,\n    "is_fake": false,\n    "title": "Data jobs — вакансии по data science, анализу данных, аналитике, искусственному ин...
# ...

# %% [markdown]
# #### Посмотрим те вакансии где есть, аналитик

# %%
telegram[telegram['text'].str.lower().str.contains('analyst')]
# Out:
#                                                                                                                                                                                                                                                                                                            chat  \
# 17  {\n    "_": "Chat",\n    "id": -1001137236002,\n    "type": "channel",\n    "is_verified": false,\n    "is_restricted": false,\n    "is_creator": false,\n    "is_scam": false,\n    "is_fake": false,\n    "title": "Job for Analysts & Data Scientists",\n    "username": "foranalysts",\n    "photo":...
# 19  {\n    "_": "Chat",\n    "id": -1001137236002,\n    "type": "channel",\n    "is_verified": false,\n    "is_restricted": false,\n    "is_creator": false,\n    "is_scam": false,\n    "is_fake": false,\n    "title": "Job for Analysts & Data Scientists",\n    "username": "foranalysts",\n    "photo":...
# ...

# %%
telegram[telegram['chat_id'] == -1001483488834]['text']
# Out:
# 0     👋Привет!\n\nПрограммист? А как хорошо ты знаешь математику?\n\n🎲 Приготовься пройти тест по математике и проверить свои знания!\n\nМы собрали 15 интересных примеров, решив которые, первые 30 человек получат сертификат на 10 тыс. рублей на обучение в онлайн-школе proglib.academy, а также те, кто ...
# 1                                                                                                                                                           👔 Data Scientist\n⛳️ ApRbot \n💼🥁Работа в офисе\n💵 60 000 - 100 000 рублей\n\nПодробнее: https://proglib.io/vacancies/data-scientist-aprbot-2022-04-11
# 2                                                                                                                                          👔 Data Scientist\n⛳️ РЕСО-Гарантия \n💼🥁Работа в офисе\n💵 Зарплата на собеседовании\n\nПодробнее: https://proglib.io/vacancies/data-scientist-reso-garantiya-2022-04-10
# ...

# %% [markdown]
# <b>Используем регулярные выражения, чтобы получить нужное в сообщениях</b>\
# https://docs.python.org/3/library/re.html \
# https://regex101.com/

# %%
ds = r'ds|scien|дс|cаен|tensorflow|pytorch'
da = r'analyst|analysis|аналитик|business intelligence|tableau'
de = r'engineer|инженер|spark|airflow'

# %% [markdown]
# #### Пометим True или False там где у нас совпадение

# %%
telegram['ds'] = telegram['text'].apply(lambda x: True if re.search(ds, x.lower()) else False)
telegram['da'] = telegram['text'].apply(lambda x: True if re.search(da, x.lower()) else False)
telegram['de'] = telegram['text'].apply(lambda x: True if re.search(de, x.lower()) else False)

# %%
telegram.head(3)
# Out:
#                                                                                                                                                                                                                                                                                                           chat  \
# 0  {\n    "_": "Chat",\n    "id": -1001483488834,\n    "type": "channel",\n    "is_verified": false,\n    "is_restricted": false,\n    "is_creator": false,\n    "is_scam": false,\n    "is_fake": false,\n    "title": "Data jobs — вакансии по data science, анализу данных, аналитике, искусственному ин...
# 1  {\n    "_": "Chat",\n    "id": -1001483488834,\n    "type": "channel",\n    "is_verified": false,\n    "is_restricted": false,\n    "is_creator": false,\n    "is_scam": false,\n    "is_fake": false,\n    "title": "Data jobs — вакансии по data science, анализу данных, аналитике, искусственному ин...
# ...

# %%
print(telegram.iloc[49]['text'])
# Out:
# #vacancy #вакансия #fulltime #удаленка #remote #data #dataengineer #dataanalyst #middle #senior #Python #Java #ETL #SQL
# 💡Всем привет! Меня зовут Оля Быканова, я HR в компании Ennabl. Ищу в команду Data Engineer уровня Middle/Senior.
#
# 🔆Компания: Ennabl (https://www.ennabl.com)
# 📍Локация: полная удалёнка (всегда была и будет!). Мы рады коллегам из разных стран.
# 🖥Занятость и оформление: full-time (5/2); оформление по ИП, которое зарегистрировано вне РФ (т.е. ИП в РФ не подходит, к сожалению, ИП в любых иных странах - подходит)
# 💰ЗП: 3 500$- 5 000$ gross
# 📩Контакт: @OlgaBykanova (https://t.me/OlgaBykanova; email: olga@ennabl.com)
#
# ⚡️Мы продуктовый финтех стартап со штаб-квартирой в США (Коннектикут) с diverse командой из 30 человек (РФ, США, Ирландия, Украина, Узбекистан, Кыргызстан, Эстония, Сербия, Индия). Создаем платформу для страховых брокеров и агентов, которая позволяет работать с данными более эффективно.
#
# 🔥Мы предлагаем:
# ...

# %%
telegram[(telegram['da']) & (telegram['ds']) & (telegram['de'])]
# Out:
#                                                                                                                                                                                                                                                                                                            chat  \
# 36  {\n    "_": "Chat",\n    "id": -1001321264581,\n    "type": "channel",\n    "is_verified": false,\n    "is_restricted": false,\n    "is_creator": false,\n    "is_scam": false,\n    "is_fake": false,\n    "title": "Data Science Jobs / AI / NN / ML / DL / NLP",\n    "username": "datasciencejobs",\...
#
#     message_id                date  \
# 36         924 2022-04-12 09:00:51
#
# ...

# %%
telegram[telegram['da']]
# Out:
#                                                                                                                                                                                                                                                                                                            chat  \
# 16  {\n    "_": "Chat",\n    "id": -1001137236002,\n    "type": "channel",\n    "is_verified": false,\n    "is_restricted": false,\n    "is_creator": false,\n    "is_scam": false,\n    "is_fake": false,\n    "title": "Job for Analysts & Data Scientists",\n    "username": "foranalysts",\n    "photo":...
# 17  {\n    "_": "Chat",\n    "id": -1001137236002,\n    "type": "channel",\n    "is_verified": false,\n    "is_restricted": false,\n    "is_creator": false,\n    "is_scam": false,\n    "is_fake": false,\n    "title": "Job for Analysts & Data Scientists",\n    "username": "foranalysts",\n    "photo":...
# ...

# %% [markdown]
# #### Чтобы нам удобно было смотреть ваканисии добавим кнопку

# %%
button = widgets.Button(description="Показать")
output = widgets.Output()

display(button, output)

counter = 0
def on_clicked(b):
    with output:
        try:
            global counter
            clear_output()
            print('№ вакансии: ', counter)
            print(telegram['text'][counter])
            counter += 1
        except Exception as e:
            print("Вакансии закончились")
            
button.on_click(on_clicked)
# Out:
# Button(description='Показать', style=ButtonStyle())
# Output()

# %% [markdown]
# ### Достанем все ссылки

# %%
def get_links(x, regexp='http\S+'): ###
    try:
        for i in json.loads(x['entities']):
            if i['type'] == 'text_link':
                return i['url']
            elif i['type'] == 'url':
                url = re.findall(regexp, x['text'])[0]
                return url
        
    except:
        return None

# %%
telegram['url'] = telegram.apply(get_links, axis=1)

# %%
telegram['url']
# Out:
# 0                                                                                         https://proglib.io/w/cff56588
# 1                                                         https://proglib.io/vacancies/data-scientist-aprbot-2022-04-11
# 2                                                 https://proglib.io/vacancies/data-scientist-reso-garantiya-2022-04-10
# 3                                                       https://proglib.io/vacancies/data-scientist-forecsys-2022-04-08
# 4                                                                                         https://proglib.io/w/77849b95
# 5     http://job.megafon.ru/vacancy/samara/produktovyj-marketing-4/data-scientist-14?utm_source=public_tg&utm_medium=ds
# 6                                                        https://proglib.io/vacancies/data-scientist-imagion-2022-04-06
# 7                                                        https://proglib.io/vacancies/data-scientist-e-promo-2022-04-04
# ...

# %% [markdown]
# ### Парсим ссылки

# %%
def parse_site(url, element='div', extra_info=None):
    try:
        data = requests.get(url).text ###
        soup = BeautifulSoup(data)
        elements = []
        for extra in extra_info:
            elements += soup.find_all(element, extra)
        html = ''
        for i in elements:
            html += str(i)
        return html
    except Exception as e:
        return '<p>Не удалось получить элемент</p>'

# %% [markdown]
# Проверим содержимое

# %%
telegram['url'][14]
# Out:
# 'https://proglib.io/vacancies/data-scientist-urent-2022-03-27'

# %%
HTML(parse_site(telegram['url'][14], extra_info=[{'class': 'list-parent vacancy-desc'}]))
# Out:
# <div class="list-parent vacancy-desc" itemprop="description">
# ...

# %% [markdown]
# Нужно перебрать все варианты блоков, где отображена информация о вакансиях.\
# Если у нас часто встречаются одни и те же сайты, можно взять доп информацию о блоке и указать ее

# %%
#заранее добавили какие есть классы на рассматриваемых сайтах

extra_infos = [{'class': 'list-parent vacancy-desc'}, 
               {'class': 'bp-Vacancy__description bp-VacancyDescription'}, 
               {'id': 'vacancy-description'},
               {'class': 'section__block panel js-show'}]

###
telegram['parsed_text'] = telegram['url'].apply(lambda x: parse_site(x, extra_info=extra_infos))

# %%
HTML(telegram['parsed_text'][14])
# Out:
# <div class="list-parent vacancy-desc" itemprop="description">
# ...

# %% [markdown]
# Выберем вакансии "Аналитик данных"

# %%
vacs_df = telegram.copy().query("da == True").reset_index(drop=True)

# %%
vacs_df
# Out:
#                                                                                                                                                                                                                                                                                                            chat  \
# 0   {\n    "_": "Chat",\n    "id": -1001137236002,\n    "type": "channel",\n    "is_verified": false,\n    "is_restricted": false,\n    "is_creator": false,\n    "is_scam": false,\n    "is_fake": false,\n    "title": "Job for Analysts & Data Scientists",\n    "username": "foranalysts",\n    "photo":...
# 1   {\n    "_": "Chat",\n    "id": -1001137236002,\n    "type": "channel",\n    "is_verified": false,\n    "is_restricted": false,\n    "is_creator": false,\n    "is_scam": false,\n    "is_fake": false,\n    "title": "Job for Analysts & Data Scientists",\n    "username": "foranalysts",\n    "photo":...
# ...

# %%
vacs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   chat         22 non-null     object
#  1   message_id   22 non-null     int64
#  2   date         22 non-null     datetime64[ns]
#  3   text         22 non-null     object
#  4   entities     22 non-null     object
#  5   chat_id      22 non-null     int64
#  6   title        22 non-null     object
#  7   ds           22 non-null     bool
#  8   da           22 non-null     bool
#  9   de           22 non-null     bool
#  10  url          21 non-null     object
#  11  parsed_text  22 non-null     object
# dtypes: bool(3), datetime64[ns](1), int64(2), object(6)
# memory usage: 1.7+ KB

# %% [markdown]
# ### Удобный просмотр

# %%
button_2 = widgets.Button(description="Показать вакансии")
output_2 = widgets.Output()

display(button_2, output_2)

counter_2 = 0
def on_clicked_2(b):
    with output_2:
        try:
            global counter_2
            clear_output()
            print('№ вакансии: ', counter_2)
            display(HTML('<h1>Источник: ' + str(vacs_df['title'][counter_2]) + '</h1>'))
            print(vacs_df['text'][counter_2])
            display(HTML(vacs_df['parsed_text'][counter_2]))
            if vacs_df['url'][counter_2]:
                display(HTML('<a href="' + str(vacs_df['url'][counter_2]) + '" target="_blank">Ссылка из поста</a>'))
            counter_2 += 1
        except Exception as e:
            print("Вакансии закончились")
            counter_2 = 0
            
button_2.on_click(on_clicked_2)
# Out:
# Button(description='Показать вакансии', style=ButtonStyle())
# Output()
